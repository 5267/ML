# %%
import ccxt
#import ccxt.async_support as ccxt

# %%
dir(ccxt)
# Out:
# ['AccountSuspended',
#  'AddressPending',
#  'ArgumentsRequired',
#  'AuthenticationError',
#  'BadRequest',
#  'BadResponse',
#  'BaseError',
#  'CancelPending',
#  'DDoSProtection',
#  'DECIMAL_PLACES',
#  'DuplicateOrderId',
#  'Exchange',
#  'ExchangeError',
#  'ExchangeNotAvailable',
#  'InsufficientFunds',
#  'InvalidAddress',
#  'InvalidNonce',
#  'InvalidOrder',
#  'NO_PADDING',
#  'NetworkError',
#  'NotSupported',
#  'NullResponse',
#  'OrderImmediatelyFillable',
#  'OrderNotCached',
#  'OrderNotFillable',
#  'OrderNotFound',
#  'PAD_WITH_ZERO',
#  'PermissionDenied',
#  'ROUND',
#  'RequestTimeout',
#  'SIGNIFICANT_DIGITS',
#  'TRUNCATE',
#  '_1btcxe',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'acx',
#  'allcoin',
#  'anxpro',
#  'anybits',
#  'base',
#  'bcex',
#  'bibox',
#  'bigone',
#  'binance',
#  'bit2c',
#  'bitbank',
#  'bitbay',
#  'bitfinex',
#  'bitfinex2',
#  'bitflyer',
#  'bitforex',
#  'bithumb',
#  'bitibu',
#  'bitkk',
#  'bitlish',
#  'bitmarket',
#  'bitmex',
#  'bitsane',
#  'bitso',
#  'bitstamp',
#  'bitstamp1',
#  'bittrex',
#  'bitz',
#  'bl3p',
#  'bleutrade',
#  'braziliex',
#  'btcalpha',
#  'btcbox',
#  'btcchina',
#  'btcexchange',
#  'btcmarkets',
#  'btctradeim',
#  'btctradeua',
#  'btcturk',
#  'buda',
#  'bxinth',
#  'ccex',
#  'cex',
#  'chbtc',
#  'chilebit',
#  'cobinhood',
#  'coinbase',
#  'coinbaseprime',
#  'coinbasepro',
#  'coincheck',
#  'coinegg',
#  'coinex',
#  'coinexchange',
#  'coinfalcon',
#  'coinfloor',
#  'coingi',
#  'coinmarketcap',
#  'coinmate',
#  'coinnest',
#  'coinone',
#  'coinspot',
#  'cointiger',
#  'coolcoin',
#  'coss',
#  'crex24',
#  'crypton',
#  'cryptopia',
#  'decimal_to_precision',
#  'deribit',
#  'dsx',
#  'errors',
#  'ethfinex',
#  'exchanges',
#  'exmo',
#  'exx',
#  'fcoin',
#  'flowbtc',
#  'foxbit',
#  'fybse',
#  'fybsg',
#  'gatecoin',
#  'gateio',
#  'gdax',
#  'gemini',
#  'getbtc',
#  'hadax',
#  'hitbtc',
#  'hitbtc2',
#  'huobipro',
#  'ice3x',
#  'independentreserve',
#  'indodax',
#  'itbit',
#  'jubi',
#  'kkex',
#  'kraken',
#  'kucoin',
#  'kucoin2',
#  'kuna',
#  'lakebtc',
#  'lbank',
#  'liqui',
#  'liquid',
#  'livecoin',
#  'luno',
#  'lykke',
#  'mercado',
#  'mixcoins',
#  'negociecoins',
#  'nova',
#  'okcoincny',
#  'okcoinusd',
#  'okex',
#  'paymium',
#  'poloniex',
#  'qryptos',
#  'quadrigacx',
#  'quoinex',
#  'rightbtc',
#  'southxchange',
#  'surbitcoin',
#  'theocean',
#  'therock',
#  'tidebit',
#  'tidex',
#  'uex',
#  'upbit',
#  'urdubit',
#  'vaultoro',
#  'vbtc',
#  'virwox',
#  'xbtce',
#  'yobit',
#  'yunbi',
#  'zaif',
#  'zb']

# %%
print(ccxt.exchanges)
# Out:
# ['_1btcxe', 'acx', 'allcoin', 'anxpro', 'anybits', 'bcex', 'bibox', 'bigone', 'binance', 'bit2c', 'bitbank', 'bitbay', 'bitfinex', 'bitfinex2', 'bitflyer', 'bitforex', 'bithumb', 'bitibu', 'bitkk', 'bitlish', 'bitmarket', 'bitmex', 'bitsane', 'bitso', 'bitstamp', 'bitstamp1', 'bittrex', 'bitz', 'bl3p', 'bleutrade', 'braziliex', 'btcalpha', 'btcbox', 'btcchina', 'btcexchange', 'btcmarkets', 'btctradeim', 'btctradeua', 'btcturk', 'buda', 'bxinth', 'ccex', 'cex', 'chbtc', 'chilebit', 'cobinhood', 'coinbase', 'coinbaseprime', 'coinbasepro', 'coincheck', 'coinegg', 'coinex', 'coinexchange', 'coinfalcon', 'coinfloor', 'coingi', 'coinmarketcap', 'coinmate', 'coinnest', 'coinone', 'coinspot', 'cointiger', 'coolcoin', 'coss', 'crex24', 'crypton', 'cryptopia', 'deribit', 'dsx', 'ethfinex', 'exmo', 'exx', 'fcoin', 'flowbtc', 'foxbit', 'fybse', 'fybsg', 'gatecoin', 'gateio', 'gdax', 'gemini', 'getbtc', 'hadax', 'hitbtc', 'hitbtc2', 'huobipro', 'ice3x', 'independentreserve', 'indodax', 'itbit', 'jubi', 'kkex', 'kraken', 'kucoin', 'kucoin2', 'kuna', 'lakebtc', 'lbank', 'liqui', 'liquid', 'livecoin', 'luno', 'lykke', 'mercado', 'mixcoins', 'negociecoins', 'nova', 'okcoincny', 'okcoinusd', 'okex', 'paymium', 'poloniex', 'qryptos', 'quadrigacx', 'quoinex', 'rightbtc', 'southxchange', 'surbitcoin', 'theocean', 'therock', 'tidebit', 'tidex', 'uex', 'upbit', 'urdubit', 'vaultoro', 'vbtc', 'virwox', 'xbtce', 'yobit', 'yunbi', 'zaif', 'zb']

# %%
dir(ccxt.okex)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_convertECSignatureToSignatureHex',
#  'account',
#  'aggregate',
#  'aiohttp_proxy',
#  'aiohttp_trust_env',
#  'amount_to_precision',
#  'api',
#  'apiKey',
#  'array_concat',
#  'asyncio_loop',
#  'balance',
#  'base64urlencode',
#  'binary_concat',
#  'binary_to_string',
#  'build_ohlcv',
#  'calculate_fee',
#  'cancel_order',
#  'capitalize',
#  'certified',
#  'check_address',
#  'check_required_credentials',
#  'check_required_dependencies',
#  'commonCurrencies',
#  'common_currency_code',
#  'convert_ohlcv_to_trading_view',
#  'convert_trading_view_to_ohlcv',
#  'cost_to_precision',
#  'create_limit_buy_order',
#  'create_limit_order',
#  'create_limit_sell_order',
#  'create_market_buy_order',
#  'create_market_order',
#  'create_market_sell_order',
#  'create_order',
#  'currencies',
#  'currencies_by_id',
#  'currency',
#  'currency_id',
#  'currency_to_precision',
#  'decode',
#  'decryptAccount',
#  'decryptAccountFromJSON',
#  'decryptAccountFromPrivateKey',
#  'deep_extend',
#  'define_rest_api',
#  'describe',
#  'dmy',
#  'edit_limit_buy_order',
#  'edit_limit_order',
#  'edit_limit_sell_order',
#  'edit_order',
#  'enableLastHttpResponse',
#  'enableLastJsonResponse',
#  'enableLastResponseHeaders',
#  'enableRateLimit',
#  'encode',
#  'encode_uri_component',
#  'eth_decimals',
#  'eth_unit',
#  'exceptions',
#  'extend',
#  'extract_params',
#  'fee_to_precision',
#  'fees',
#  'fetch',
#  'fetch2',
#  'fetchOHLCV',
#  'fetch_balance',
#  'fetch_bids_asks',
#  'fetch_closed_orders',
#  'fetch_currencies',
#  'fetch_deposits',
#  'fetch_fees',
#  'fetch_free_balance',
#  'fetch_l2_order_book',
#  'fetch_markets',
#  'fetch_my_trades',
#  'fetch_ohlcv',
#  'fetch_open_orders',
#  'fetch_order',
#  'fetch_order_book',
#  'fetch_order_status',
#  'fetch_order_trades',
#  'fetch_orders',
#  'fetch_partial_balance',
#  'fetch_ticker',
#  'fetch_tickers',
#  'fetch_tickers_from_api',
#  'fetch_tickers_from_web',
#  'fetch_total_balance',
#  'fetch_trades',
#  'fetch_transactions',
#  'fetch_used_balance',
#  'fetch_withdrawals',
#  'filterBy',
#  'filter_by',
#  'filter_by_array',
#  'filter_by_currency_since_limit',
#  'filter_by_since_limit',
#  'filter_by_symbol',
#  'filter_by_symbol_since_limit',
#  'filter_by_value_since_limit',
#  'find_broadly_matched_key',
#  'find_market',
#  'find_symbol',
#  'fromWei',
#  'getZeroExOrderHash',
#  'getZeroExOrderHash2',
#  'getZeroExOrderHashV2',
#  'get_create_date_field',
#  'get_orders_field',
#  'groupBy',
#  'group_by',
#  'gzip_deflate',
#  'handle_errors',
#  'handle_rest_errors',
#  'handle_rest_response',
#  'has',
#  'has_web3',
#  'hash',
#  'hashMessage',
#  'headers',
#  'hmac',
#  'hostname',
#  'httpExceptions',
#  'id',
#  'ids',
#  'implode_params',
#  'in_array',
#  'index_by',
#  'is_empty',
#  'is_json_encoded_object',
#  'iso8601',
#  'json',
#  'jwt',
#  'keysort',
#  'lastRestPollTimestamp',
#  'lastRestRequestTimestamp',
#  'last_http_response',
#  'last_json_response',
#  'last_response_headers',
#  'limits',
#  'load_accounts',
#  'load_fees',
#  'load_markets',
#  'load_trading_limits',
#  'logger',
#  'market',
#  'market_id',
#  'market_ids',
#  'markets',
#  'marketsById',
#  'markets_by_id',
#  'microseconds',
#  'milliseconds',
#  'minFundingAddressLength',
#  'msec',
#  'nonce',
#  'oath',
#  'omit',
#  'options',
#  'orderbooks',
#  'ordered',
#  'orders',
#  'origin',
#  'parse8601',
#  'parseJsonResponse',
#  'parse_balance',
#  'parse_bid_ask',
#  'parse_bids_asks',
#  'parse_date',
#  'parse_json',
#  'parse_ledger',
#  'parse_ohlcv',
#  'parse_ohlcvs',
#  'parse_order',
#  'parse_order_book',
#  'parse_order_side',
#  'parse_order_status',
#  'parse_orders',
#  'parse_ticker',
#  'parse_timeframe',
#  'parse_trade',
#  'parse_trades',
#  'parse_trading_view_ohlcv',
#  'parse_transactions',
#  'password',
#  'pluck',
#  'populate_fees',
#  'precision',
#  'precisionMode',
#  'precision_from_string',
#  'prepare_request_headers',
#  'price_to_precision',
#  'privateKey',
#  'proxies',
#  'proxy',
#  'purge_cached_orders',
#  'raise_error',
#  'rateLimit',
#  'rateLimitMaxTokens',
#  'rateLimitTokens',
#  'rateLimitUpdateTime',
#  'rawencode',
#  'remove_0x_prefix',
#  'request',
#  'requiredCredentials',
#  'requiresWeb3',
#  'restPollerLoopIsRunning',
#  'restRequestQueue',
#  'safe_currency_code',
#  'safe_either',
#  'safe_float',
#  'safe_float_2',
#  'safe_integer',
#  'safe_integer_2',
#  'safe_string',
#  'safe_string_2',
#  'safe_value',
#  'safe_value_2',
#  'sec',
#  'seconds',
#  'secret',
#  'session',
#  'set_markets',
#  'set_sandbox_mode',
#  'sign',
#  'signHash',
#  'signMessage',
#  'signZeroExOrder',
#  'signZeroExOrderV2',
#  'soliditySha256',
#  'soliditySha3',
#  'solidityTypes',
#  'solidityValues',
#  'sort_by',
#  'substituteCommonCurrencyCodes',
#  'sum',
#  'symbols',
#  'throttle',
#  'tickers',
#  'timeout',
#  'toWei',
#  'to_array',
#  'totp',
#  'trades',
#  'transactions',
#  'truncate',
#  'truncate_to_string',
#  'twofa',
#  'uid',
#  'unique',
#  'unjson',
#  'url',
#  'urlencode',
#  'usec',
#  'userAgent',
#  'userAgents',
#  'uuid',
#  'verbose',
#  'version',
#  'walletAddress',
#  'web3',
#  'withdraw',
#  'ymd',
#  'ymdhms']

# %%
help(ccxt.okex)

# %% [markdown]
#  'account',
#  'aggregate',
#  'aiohttp_proxy',
#  'aiohttp_trust_env',
#  'amount_to_precision',
#  'api',
#  'apiKey',
#  'array_concat',
#  'asyncio_loop',
#  'balance',
#  'base64urlencode',
#  'binary_concat',
#  'binary_to_string',
#  'build_ohlcv',
#  'calculate_fee',
#  'cancel_order',
#  'capitalize',
#  'certified',
#  'check_address',
#  'check_required_credentials',
#  'check_required_dependencies',
#  'commonCurrencies',
#  'common_currency_code',
#  'convert_ohlcv_to_trading_view',
#  'convert_trading_view_to_ohlcv',
#  'cost_to_precision',
#  'create_limit_buy_order',
#  'create_limit_order',
#  'create_limit_sell_order',
#  'create_market_buy_order',
#  'create_market_order',
#  'create_market_sell_order',
#  'create_order',
#  'currencies',
#  'currencies_by_id',
#  'currency',
#  'currency_id',
#  'currency_to_precision',
#  'decode',
#  'decryptAccount',
#  'decryptAccountFromJSON',
#  'decryptAccountFromPrivateKey',
#  'deep_extend',
#  'define_rest_api',
#  'describe',
#  'dmy',
#  'edit_limit_buy_order',
#  'edit_limit_order',
#  'edit_limit_sell_order',
#  'edit_order',
#  'enableLastHttpResponse',
#  'enableLastJsonResponse',
#  'enableLastResponseHeaders',
#  'enableRateLimit',
#  'encode',
#  'encode_uri_component',
#  'eth_decimals',
#  'eth_unit',
#  'exceptions',
#  'extend',
#  'extract_params',
#  'fee_to_precision',
#  'fees',
#  'fetch',
#  'fetch2',
#  'fetchOHLCV',
#  'fetch_balance',
#  'fetch_bids_asks',
#  'fetch_closed_orders',
#  'fetch_currencies',
#  'fetch_deposits',
#  'fetch_fees',
#  'fetch_free_balance',
#  'fetch_l2_order_book',
#  'fetch_markets',
#  'fetch_my_trades',
#  'fetch_ohlcv',
#  'fetch_open_orders',
#  'fetch_order',
#  'fetch_order_book',
#  'fetch_order_status',
#  'fetch_order_trades',
#  'fetch_orders',
#  'fetch_partial_balance',
#  'fetch_ticker',
#  'fetch_tickers',
#  'fetch_tickers_from_api',
#  'fetch_tickers_from_web',
#  'fetch_total_balance',
#  'fetch_trades',
#  'fetch_transactions',
#  'fetch_used_balance',
#  'fetch_withdrawals',
#  'filterBy',
#  'filter_by',
#  'filter_by_array',
#  'filter_by_currency_since_limit',
#  'filter_by_since_limit',
#  'filter_by_symbol',
#  'filter_by_symbol_since_limit',
#  'filter_by_value_since_limit',
#  'find_broadly_matched_key',
#  'find_market',
#  'find_symbol',
#  'fromWei',
#  'getZeroExOrderHash',
#  'getZeroExOrderHash2',
#  'getZeroExOrderHashV2',
#  'get_create_date_field',
#  'get_orders_field',
#  'groupBy',
#  'group_by',
#  'gzip_deflate',
#  'handle_errors',
#  'handle_rest_errors',
#  'handle_rest_response',
#  'has',
#  'has_web3',
#  'hash',
#  'hashMessage',
#  'headers',
#  'hmac',
#  'hostname',
#  'httpExceptions',
#  'id',
#  'ids',
#  'implode_params',
#  'in_array',
#  'index_by',
#  'is_empty',
#  'is_json_encoded_object',
#  'iso8601',
#  'json',
#  'jwt',
#  'keysort',
#  'lastRestPollTimestamp',
#  'lastRestRequestTimestamp',
#  'last_http_response',
#  'last_json_response',
#  'last_response_headers',
#  'limits',
#  'load_accounts',
#  'load_fees',
#  'load_markets',
#  'load_trading_limits',
#  'logger',
#  'market',
#  'market_id',
#  'market_ids',
#  'markets',
#  'marketsById',
#  'markets_by_id',
#  'microseconds',
#  'milliseconds',
#  'minFundingAddressLength',
#  'msec',
#  'nonce',
#  'oath',
#  'omit',
#  'options',
#  'orderbooks',
#  'ordered',
#  'orders',
#  'origin',
#  'parse8601',
#  'parseJsonResponse',
#  'parse_balance',
#  'parse_bid_ask',
#  'parse_bids_asks',
#  'parse_date',
#  'parse_json',
#  'parse_ledger',
#  'parse_ohlcv',
#  'parse_ohlcvs',
#  'parse_order',
#  'parse_order_book',
#  'parse_order_side',
#  'parse_order_status',
#  'parse_orders',
#  'parse_ticker',
#  'parse_timeframe',
#  'parse_trade',
#  'parse_trades',
#  'parse_trading_view_ohlcv',
#  'parse_transactions',
#  'password',
#  'pluck',
#  'populate_fees',
#  'precision',
#  'precisionMode',
#  'precision_from_string',
#  'prepare_request_headers',
#  'price_to_precision',
#  'privateKey',
#  'proxies',
#  'proxy',
#  'purge_cached_orders',
#  'raise_error',
#  'rateLimit',
#  'rateLimitMaxTokens',
#  'rateLimitTokens',
#  'rateLimitUpdateTime',
#  'rawencode',
#  'remove_0x_prefix',
#  'request',
#  'requiredCredentials',
#  'requiresWeb3',
#  'restPollerLoopIsRunning',
#  'restRequestQueue',
#  'safe_currency_code',
#  'safe_either',
#  'safe_float',
#  'safe_float_2',
#  'safe_integer',
#  'safe_integer_2',
#  'safe_string',
#  'safe_string_2',
#  'safe_value',
#  'safe_value_2',
#  'sec',
#  'seconds',
#  'secret',
#  'session',
#  'set_markets',
#  'set_sandbox_mode',
#  'sign',
#  'signHash',
#  'signMessage',
#  'signZeroExOrder',
#  'signZeroExOrderV2',
#  'soliditySha256',
#  'soliditySha3',
#  'solidityTypes',
#  'solidityValues',
#  'sort_by',
#  'substituteCommonCurrencyCodes',
#  'sum',
#  'symbols',
#  'throttle',
#  'tickers',
#  'timeout',
#  'toWei',
#  'to_array',
#  'totp',
#  'trades',
#  'transactions',
#  'truncate',
#  'truncate_to_string',
#  'twofa',
#  'uid',
#  'unique',
#  'unjson',
#  'url',
#  'urlencode',
#  'usec',
#  'userAgent',
#  'userAgents',
#  'uuid',
#  'verbose',
#  'version',
#  'walletAddress',
#  'web3',
#  'withdraw',
#  'ymd',
#  'ymdhms'

# %%
market = ccxt.okex()
help(market.fetchOhlcv)
# Out:
# Help on method fetch_ohlcv in module ccxt.okcoinusd:
#
# fetch_ohlcv(symbol, timeframe='1m', since=None, limit=None, params={}) method of ccxt.okex.okex instance

# %%
market.fetchOhlcv('ltc_usd',limit=100)
# Out:
# ---------------------------------------------------------------------
# timeout                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     145                 self, "Connection to %s timed out. (connect timeout=%s)" %
# --> 146                 (self.host, self.timeout))
#     147
#
# ConnectTimeoutError: (<urllib3.connection.VerifiedHTTPSConnection object at 0x00000000087F79B0>, 'Connection to www.okex.com timed out. (connect timeout=10)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                       Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='www.okex.com', port=443): Max retries exceeded with url: /v2/spot/markets/products (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x00000000087F79B0>, 'Connection to www.okex.com timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                      Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     380                 timeout=int(self.timeout / 1000),
# --> 381                 proxies=self.proxies
#     382             )
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     503                 if not isinstance(e.reason, NewConnectionError):
# --> 504                     raise ConnectTimeout(e, request=request)
#     505
#
# ConnectTimeout: HTTPSConnectionPool(host='www.okex.com', port=443): Max retries exceeded with url: /v2/spot/markets/products (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x00000000087F79B0>, 'Connection to www.okex.com timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# RequestTimeout                      Traceback (most recent call last)
# <ipython-input-11-bdd344425aad> in <module>()
# ----> 1 market.fetchOhlcv('ltc_usd',limit=100)
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\okcoinusd.py in fetch_ohlcv(self, symbol, timeframe, since, limit, params)
#     395
#     396     def fetch_ohlcv(self, symbol, timeframe='1m', since=None, limit=None, params={}):
# --> 397         self.load_markets()
#     398         market = self.market(symbol)
#     399         method = 'publicGet'
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in load_markets(self, reload)
#     975                     return self.set_markets(self.markets)
#     976                 return self.markets
# --> 977         markets = self.fetch_markets()
#     978         currencies = None
#     979         if self.has['fetchCurrencies']:
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\okex.py in fetch_markets(self)
#      59
#      60     def fetch_markets(self):
# ---> 61         markets = super(okex, self).fetch_markets()
#      62         # TODO: they have a new fee schedule as of Feb 7
#      63         # the new fees are progressive and depend on 30-day traded volume
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\okcoinusd.py in fetch_markets(self)
#     186
#     187     def fetch_markets(self):
# --> 188         response = self.webGetSpotMarketsProducts()
#     189         markets = response['data']
#     190         result = []
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in request(self, path, api, method, params, headers, body)
#     328
#     329     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# --> 330         return self.fetch2(path, api, method, params, headers, body)
#     331
#     332     @staticmethod
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in fetch2(self, path, api, method, params, headers, body)
#     325         self.lastRestRequestTimestamp = self.milliseconds()
#     326         request = self.sign(path, api, method, params, headers, body)
# --> 327         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     328
#     329     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     389
#     390         except Timeout as e:
# --> 391             self.raise_error(RequestTimeout, method, url, e)
#     392
#     393         except TooManyRedirects as e:
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in raise_error(self, exception_type, url, method, error, details)
#     310             error = str(error)
#     311         output = ' '.join([self.id] + [var for var in (url, method, error, details) if var is not None])
# --> 312         raise exception_type(output)
#     313
#     314     def throttle(self):
#
# RequestTimeout: okex GET https://www.okex.com/v2/spot/markets/products HTTPSConnectionPool(host='www.okex.com', port=443): Max retries exceeded with url: /v2/spot/markets/products (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x00000000087F79B0>, 'Connection to www.okex.com timed out. (connect timeout=10)'))

# %%
# coding=utf-8

import ccxt

hitbtc = ccxt.hitbtc({'verbose': True})
bitmex = ccxt.bitmex()
huobi  = ccxt.huobi()
exmo   = ccxt.exmo({
    'apiKey': 'YOUR_PUBLIC_API_KEY',
    'secret': 'YOUR_SECRET_PRIVATE_KEY',
})
kraken = ccxt.kraken({
    'apiKey': 'YOUR_PUBLIC_API_KEY',
    'secret': 'YOUR_SECRET_PRIVATE_KEY',
})

exchange_id = 'binance'
exchange_class = getattr(ccxt, exchange_id)
exchange = exchange_class({
    'apiKey': 'YOUR_API_KEY',
    'secret': 'YOUR_SECRET',
    'timeout': 30000,
    'enableRateLimit': True,
})

hitbtc_markets = hitbtc.load_markets()

print(hitbtc.id, hitbtc_markets)
print(bitmex.id, bitmex.load_markets())
print(huobi.id, huobi.load_markets())

print(hitbtc.fetch_order_book(hitbtc.symbols[0]))
print(bitmex.fetch_ticker('BTC/USD'))
print(huobi.fetch_trades('LTC/CNY'))

print(exmo.fetch_balance())

# sell one ฿ for market price and receive $ right now
print(exmo.id, exmo.create_market_sell_order('BTC/USD', 1))

# limit buy BTC/EUR, you pay €2500 and receive ฿1  when the order is closed
print(exmo.id, exmo.create_limit_buy_order('BTC/EUR', 1, 2500.00))

# pass/redefine custom exchange-specific order params: type, amount, price, flags, etc...
kraken.create_market_buy_order('BTC/USD', 1, {'trading_agreement': 'agree'})
# Out:
# Request: GET http://api.hitbtc.com/api/1/public/symbols {'User-Agent': 'python-requests/2.20.1', 'Accept-Encoding': 'gzip, deflate'} None
# ---------------------------------------------------------------------
# timeout                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     145                 self, "Connection to %s timed out. (connect timeout=%s)" %
# --> 146                 (self.host, self.timeout))
#     147
#
# ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x0000000008A0E518>, 'Connection to api.hitbtc.com timed out. (connect timeout=10)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                       Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='api.hitbtc.com', port=80): Max retries exceeded with url: /api/1/public/symbols (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000000008A0E518>, 'Connection to api.hitbtc.com timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                      Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     380                 timeout=int(self.timeout / 1000),
# --> 381                 proxies=self.proxies
#     382             )
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# ~\AppData\Roaming\Python\Python36\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     503                 if not isinstance(e.reason, NewConnectionError):
# --> 504                     raise ConnectTimeout(e, request=request)
#     505
#
# ConnectTimeout: HTTPConnectionPool(host='api.hitbtc.com', port=80): Max retries exceeded with url: /api/1/public/symbols (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000000008A0E518>, 'Connection to api.hitbtc.com timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# RequestTimeout                      Traceback (most recent call last)
# <ipython-input-12-9ed2bf47b534> in <module>()
#      24 })
#      25
# ---> 26 hitbtc_markets = hitbtc.load_markets()
#      27
#      28 print(hitbtc.id, hitbtc_markets)
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in load_markets(self, reload)
#     975                     return self.set_markets(self.markets)
#     976                 return self.markets
# --> 977         markets = self.fetch_markets()
#     978         currencies = None
#     979         if self.has['fetchCurrencies']:
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\hitbtc.py in fetch_markets(self)
#     507
#     508     def fetch_markets(self):
# --> 509         markets = self.publicGetSymbols()
#     510         result = []
#     511         for p in range(0, len(markets['symbols'])):
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\hitbtc.py in request(self, path, api, method, params, headers, body)
#     911
#     912     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# --> 913         response = self.fetch2(path, api, method, params, headers, body)
#     914         if 'code' in response:
#     915             if 'ExecutionReport' in response:
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in fetch2(self, path, api, method, params, headers, body)
#     325         self.lastRestRequestTimestamp = self.milliseconds()
#     326         request = self.sign(path, api, method, params, headers, body)
# --> 327         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     328
#     329     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     389
#     390         except Timeout as e:
# --> 391             self.raise_error(RequestTimeout, method, url, e)
#     392
#     393         except TooManyRedirects as e:
#
# ~\AppData\Roaming\Python\Python36\site-packages\ccxt\base\exchange.py in raise_error(self, exception_type, url, method, error, details)
#     310             error = str(error)
#     311         output = ' '.join([self.id] + [var for var in (url, method, error, details) if var is not None])
# --> 312         raise exception_type(output)
#     313
#     314     def throttle(self):
#
# RequestTimeout: hitbtc GET http://api.hitbtc.com/api/1/public/symbols HTTPConnectionPool(host='api.hitbtc.com', port=80): Max retries exceeded with url: /api/1/public/symbols (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000000008A0E518>, 'Connection to api.hitbtc.com timed out. (connect timeout=10)'))
